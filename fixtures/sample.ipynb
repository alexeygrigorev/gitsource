# %% [markdown]
# # Sample Notebook
#
# This is a sample notebook for testing gitsource.

# %%
print("Hello from gitsource!")
# Out:
# Hello from gitsource!

# %% [markdown]
# ## Code Example
#
# Here's how to use the library:

# %%
from gitsource import GithubRepositoryDataReader, notebook_processor

reader = GithubRepositoryDataReader(
    repo_owner="alexeygrigorev",
    repo_name="gitsource",
    allowed_extensions={"md", "ipynb"},
    processors={"ipynb": notebook_processor},
)

files = reader.read()
